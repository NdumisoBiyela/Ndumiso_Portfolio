# %%
from google_play_scraper import reviews, Sort
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import seaborn as sns

# %%
result, continuation_token = reviews(app_id='com.ashwhale.sepush.eskom',lang='en',country='us',sort=Sort.NEWEST)

# %%
result
# Out:
# [{'reviewId': '81139d58-02e0-4545-8d4e-3a6ab72de837',
#   'userName': 'Pule Matlho',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVpSPO7VHipJ-Olg51OtMkLw5jcgaPVf5fw3sVBhdWUKQkMHS-l',
#   'content': 'Exceptional experience with updates. Always keeping me updated about power outages and stability. Best App by far!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 9, 12, 17, 19, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '52e3a65a-9c40-4a3a-8f21-f0dada755b6f',
#   'userName': 'Isaac Malau',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlcO7MhqITSUv3I-faoGISzSssZdY-pt0BDXS23mhqLFcHmspl',
#   'content': 'Great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.3.0',
#   'at': datetime.datetime(2024, 9, 11, 23, 6, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.3.0'},
#  {'reviewId': 'ca8d7492-6a44-4ba1-a280-23145b227341',
#   'userName': 'Ernest Nkosi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKJo5ksyGXEuGQBeeqS5cN_r7QMOOkHqr61kjYvL5sB_02uhA=mo',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.3.0',
#   'at': datetime.datetime(2024, 9, 10, 11, 56, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.3.0'},
#  {'reviewId': '465b6491-9ace-4cf8-8430-1bbb14417627',
#   'userName': 'Prosperous xumani ndlovu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKzBqSJtDlwHpP_s5zgtHRb2bmSb9ndtLAbyYohn3NzAg-ay64=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.3.0',
#   'at': datetime.datetime(2024, 9, 9, 19, 47, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.3.0'},
#  {'reviewId': 'ddb45990-26ec-43a3-a8b8-b3512abfe7b1',
#   'userName': 'Julia Nkadimeng',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLTHcyoiONPI6nSDJXKit-uK01pxcsj-oknwNnd5Csy0RxsuQ=mo',
#   'content': 'Not gonna say much but this app helps me know when the electricity is leaving and is a good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 9, 8, 21, 51, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'b059af33-a29d-481b-839a-0fe2b12b8ea5',
#   'userName': 'Nicoline Kriel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLlagBpvDnaWHYf9b079mYftjhV0jx1kBHYKIhMeWg90eeMPg=mo',
#   'content': "A Great accurate app only that it has been updated a little late sometimes 😔😕. But that only happened about 3? times in the last 2 years😐. So... That's great🎉🎇! It allows you to chat with community about weather, electric problems(cable issues etc.), even remind them about special days 💞 and so much more! It also has filters for all the nasty things people might try to say on ESP😌🥰! So no WhatsApp with all those nasty group chats😋! It would be amazing if it contained informed weatherups",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.3.0',
#   'at': datetime.datetime(2024, 9, 8, 16, 1, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.3.0'},
#  {'reviewId': 'c36fd5e7-f0f4-47fa-b580-8ed67d2c6a93',
#   'userName': 'Heinrich Bosch',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlIa29vVJX_Jja45C654qbOqKGxVrb5SYsNBU3CUflWNUSC_E',
#   'content': 'This app suck because complaining about things will never help, also we dont have loadshedding anymore, also they back chat their customers',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.8.9',
#   'at': datetime.datetime(2024, 9, 5, 10, 20, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.8.9'},
#  {'reviewId': 'f7900b8f-e3df-462d-b889-033ba8f76354',
#   'userName': 'Paul B',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL4fjz8QYgYc0aMgtO5OJsvDJgIEC2VUJLwXbCUeQ-dPl5ySg=mo',
#   'content': '5 stars for load shedding notifications. 2 stars removed for the fake neighbourhood chats. App uninstalled.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.2.1',
#   'at': datetime.datetime(2024, 9, 2, 7, 3, 27),
#   'replyContent': "Fake chats? Please let me know and I'll fix it ASAP jeff@esp.info",
#   'repliedAt': datetime.datetime(2024, 9, 2, 7, 47, 8),
#   'appVersion': '3.2.1'},
#  {'reviewId': '02e3d1a5-ade7-40f1-9a45-952ed6a18a6f',
#   'userName': 'Mr Kelly',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXLktT1eUV1Ys2iMMqP19dXIUUS1GIqHPACR7Qpb6W-yxkkhDQC',
#   'content': 'Love the name ESP "EskomSePush😭👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 9, 1, 17, 10, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.2.0'},
#  {'reviewId': 'b3427a89-587e-462e-b4cd-1e37ee3b496c',
#   'userName': 'Nyasha Murisa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKeSPUP23ADVbwwNUGSjISOKPYX6zszxe1mUkrmRA7KiCFhIA=mo',
#   'content': 'Domestic worker',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 8, 29, 6, 18, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.2.0'},
#  {'reviewId': '32bd1707-c6cd-466f-9c32-cc6730788c62',
#   'userName': 'keitumetse lephadi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJmLWhljKijAGVGSPfgehsoTO_r4Vf0ynguzx53A58joePx5g=mo',
#   'content': 'I think the app should have an update for the whole week. 7 days',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.23.3',
#   'at': datetime.datetime(2024, 8, 28, 20, 34, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.3'},
#  {'reviewId': '302583a6-d437-45c2-9536-e51b89f5c116',
#   'userName': 'Tebello Kholoanyane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUhOT7tOwmneR3g-rmfXJ5miTDJZgJ2f_rPrmxUSB9f-1zqp_E',
#   'content': 'Why is my app not showing reduction schedule even after updating?',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 8, 27, 14, 57, 14),
#   'replyContent': 'Hi, please let us know your Area at support@esp.info and we will figure out why you are not able to see load reduction',
#   'repliedAt': datetime.datetime(2024, 8, 27, 15, 31, 43),
#   'appVersion': '4.2.0'},
#  {'reviewId': 'fc2b1727-370c-452f-b182-f36cd6e02ee6',
#   'userName': 'Josias Lediga',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIfWXqJXyNeD3hdp6Wo1DdtFCTjdMkFDashT4gzuhl5YuNNfw=mo',
#   'content': "It doesn't disappoint",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 8, 26, 21, 49, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'b1bd0c3e-af29-409d-afb8-0cc07aaa04a9',
#   'userName': 'Sylvia Xaba',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVITY0ui16P4aTFS5aiRTfwSYGyhYj7Mau4VUzuq0o4ZdAgsDY',
#   'content': 'good',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 8, 26, 20, 45, 1),
#   'replyContent': 'Hi, you gave us only 1 star ⭐ if you like the app, please give us 5 stars rating. If you have any suggestions, please let us know at support@esp.info.',
#   'repliedAt': datetime.datetime(2024, 8, 26, 21, 7, 31),
#   'appVersion': '4.2.0'},
#  {'reviewId': '475e73d4-31d3-4778-813a-9d0d0df05e95',
#   'userName': 'Catharina maria Minders',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXrrOKtm6z5DW_odn8XkS9W-fzqK0ci8EqYjJcHQEpzzTdnDrlJ',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 25, 12, 48, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.2'},
#  {'reviewId': '86a6847a-dcf9-4ca3-b7ed-418310fd6a23',
#   'userName': 'William Henry Mitchell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLqeWy1mfQZw85iV70YaYb_B78QUUWqn6kIFEevvihxPgOY3Q=mo',
#   'content': 'Positive',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.27.3',
#   'at': datetime.datetime(2024, 8, 24, 11, 45, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.27.3'},
#  {'reviewId': 'b97a0a43-f28f-4074-94d1-9e8a551bea67',
#   'userName': 'Adrian Bonafede',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUoX17cJEm0KHiT8zgqPYqLzhFfLHiprNN3sKOYB9kTJ0YS4HqOSw',
#   'content': 'Great app and you can chat',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 8, 24, 11, 41, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.2.0'},
#  {'reviewId': 'ccfd2b7c-4f47-42e0-807c-6bac4d646927',
#   'userName': 'Tshego Shaun',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUECY6Yau38RU9m1D16BZ09ozBRJMa8AF79B7DsWOUDgmPs1pj5',
#   'content': 'I got the wrong information at first but now everything is fixed and love this app on keeping us updated for load shedding schedule',
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.2.0',
#   'at': datetime.datetime(2024, 8, 23, 5, 19, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.2.0'},
#  {'reviewId': 'c5a5ba19-c148-432e-a1da-967968fd31f0',
#   'userName': 'Ben VanderMerwe',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUUHrcggG5IFOzFKr9M5_VhKSkY_R2J-Fk7mtS-TWEQw1-=mo',
#   'content': "Reliable, helps with schedule & planning. Updated on 20 August '24. Downgraded from 5 to 1 star. Of no use as in the past after upgrade. No community notices accessible, can only post in my zone and cannot read other posts. Now only municipal posts re weather warnings.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 20, 14, 34, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.2'},
#  {'reviewId': '13e98cfd-bce8-4deb-b75e-ec873fd7a793',
#   'userName': 'Watson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK3mTtH5UDtUV0wKM6tVu49h6BDxGgmeT1z2rC8ZZ0n2f0f6g=mo',
#   'content': 'Good to advise',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 19, 7, 26, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.2'},
#  {'reviewId': '02d2264f-b130-4a10-914a-65297ac43b25',
#   'userName': 'Vivienne Steenkamp',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIrW_AxZYV-ZPLxykIVUdelqltJurpz449mHVwtdyhoHGalFA=mo',
#   'content': 'At the moment, I cannot add my town, then it says, " something went wrong", very annoying. That is why it receive only 3 stars. Previously I did not experienced this problem.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 17, 23, 43, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.2'},
#  {'reviewId': 'b6b96320-5477-4c5c-940c-7b6f3987baed',
#   'userName': 'Mnqobi Mhlanga',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLwxuwUO1uthNE7JkvRnOpRxOusEaj7XG7UYpRUwsZsGSveZg=mo',
#   'content': "Why does the story change from load shedding to be called load reduction whereas it's still same thing and now it's worse as it sometimes go for the whole day or a few days",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.23.2',
#   'at': datetime.datetime(2024, 8, 17, 19, 55, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.2'},
#  {'reviewId': 'c048b821-8609-4875-96a8-2e98781096ac',
#   'userName': 'John Skeva',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIhOxNVrRFMoMcsxH9Z3t8hE47JbAEhuidObKAaVwVU70JRXQ=mo',
#   'content': 'Very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 8, 13, 20, 42, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '5aa912b6-c8fe-4567-837b-045e509d8049',
#   'userName': 'got Lex',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX87GvOPkdUNuiKWUuuOVeIvPd0Fel3fe3ER2tmDWcGRKMnF8Q',
#   'content': 'Julle is Puik! Baie dankie vir hierdie App en die feit dat enige persoon dit gratis kan gebruik. Absolute Ysters!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 8, 11, 9, 9, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.0'},
#  {'reviewId': '0d6f89c5-039c-4d5e-aa55-783430d15e6b',
#   'userName': 'Leigh Padayachey',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIj7ismxQiPrPvWMrAXi0F1zkAUuCjLTMES0ArpxVBrieMtTQ=mo',
#   'content': 'App is working 100%',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 9, 9, 56, 25),
#   'replyContent': 'Should be fixed :)',
#   'repliedAt': datetime.datetime(2024, 8, 9, 9, 37, 42),
#   'appVersion': '4.1.2'},
#  {'reviewId': '8a423330-6e29-4671-963a-a44fea53e574',
#   'userName': 'Tshidi tshabalala',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLyv9g4K7YmNpWZbDf5IyMiAgTtDqNFh9-BA8QoifQ7WbX-yw=mo',
#   'content': "I like this app, it's been reliable during Loadshedding. I'll also like to be notified about Load reduction in Mofolo North A(6) please",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 3, 17, 14, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.2'},
#  {'reviewId': 'e9a4753e-e050-4638-8207-971f12407939',
#   'userName': 'Brian Painting',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKqTBupYl-0JqJRFsUIa2_TjsNtINxBRxAmOYvifhm0ipd5rQ=mo',
#   'content': "The latest update is nonsense sorry to say, but I can't find any info on my area, I press my area and I don't who else has reported issues",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.2',
#   'at': datetime.datetime(2024, 8, 2, 7, 46, 1),
#   'replyContent': "That doesn't sound right! Can you give us more information and share your ideas at support@esp.info so that we can investigate.",
#   'repliedAt': datetime.datetime(2024, 8, 2, 7, 55, 32),
#   'appVersion': '4.1.2'},
#  {'reviewId': '5a3fec32-315e-4604-aaa2-f71c1f19c929',
#   'userName': 'Notfound',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJS5VWXY96DQgCwnQpT1et6MH77jh8UXNn2CxA9fGDdz-0VQ=mo',
#   'content': "The app is good they not incharge of loadshedding so they never do anything the app notifies us off water and electricity we would love more updates but recently it hasn't and stopped updating us about imp stuff 😞",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 8, 1, 20, 59, 54),
#   'replyContent': 'better?',
#   'repliedAt': datetime.datetime(2024, 8, 9, 9, 38, 8),
#   'appVersion': None},
#  {'reviewId': '4a5ac666-caee-4807-8302-d96035129c3e',
#   'userName': 'Cherrie de Klerk',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPXKncASrbDRbl-TWCtvDRZzwNzq5uaNpXXokjAwwrbrUAC5I=mo',
#   'content': "What happened to Ask My Street on this app. A person used to find out quicker what was going on with the power when we were able to get into Ask My Street. But now there's no more such thing. Now we report the outage and there's no more Ask My Street. This is unacceptable.",
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 8, 1, 7, 9, 2),
#   'replyContent': '👋 the chats are now in the area so you can easily update others in your area just like we do for loadshedding! Please email us support@esp.info we keep on working to improve the experience',
#   'repliedAt': datetime.datetime(2024, 8, 1, 7, 33, 37),
#   'appVersion': '4.1.1'},
#  {'reviewId': 'a878dc88-b419-4df6-b58a-4967d54d37cf',
#   'userName': 'Gwillym Pitt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWXKxVFa3WHwa8QCXEY3Ppen0c2IHNdSWiY8IHKbO9TVgUAEAZS',
#   'content': 'Great job guys. Keep up the good work 👏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 31, 8, 20, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': 'f8ff12f7-d9a5-4dc2-9f8c-8643e6854e35',
#   'userName': 'Afeni Lukhele',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJe-_paA1R2BI8--z0KIVyLyZG86zHFhEcjEFf0_6YeW571dg=mo',
#   'content': "Last year this app was highly reliable but, now it's not. We've had a number of load reductions, power outages and load shedding in my area and all the app would say is, there is no load shedding. I don't know who you fired, but get them back!",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 30, 10, 36, 48),
#   'replyContent': "Haha Jeff is still working here. Can you email us your area name and we can check why you don't see.load reduction. Email us here support@esp.info",
#   'repliedAt': datetime.datetime(2024, 7, 30, 10, 39, 46),
#   'appVersion': '4.1.1'},
#  {'reviewId': '349c013f-bdd3-41e6-bc2d-0c15fee94715',
#   'userName': 'Josefa King',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWQFSyA8q7UyjjzrSqyxkb1q6vGWf58zeWQPYQx1QOT7LHlrpQ',
#   'content': '"What\'s going on now? This app is no longer useful at all. Even when there\'s load shedding, it says \'no load shedding today.\' It\'s time to switch."',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 7, 29, 5, 55, 3),
#   'replyContent': "Hi there definitely isn't any loadshedding right now. Might be load reduction. Email me at support@esp.info with your area and I'll check it out",
#   'repliedAt': datetime.datetime(2024, 7, 29, 7, 19, 9),
#   'appVersion': None},
#  {'reviewId': 'b9d57347-bab8-405d-9a20-831ef28f9fd2',
#   'userName': 'Lebo Thobejane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWq536EyHKCMQzYdJHxq1JUIp1Az9jcJq0dLoW9JA21nJrDw2kw',
#   'content': 'The new update took away the super valuable Ask my street. You can see what other neighbourhoods are saying and hearing, you just have your own silo which is limited for water and electricity updates. Please bring it back',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 28, 10, 35, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': '6e3fa42d-6fa8-4273-a7f6-11127d10d625',
#   'userName': 'Noxolo Ntuli',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIG4zHN8bBJ69WbwY_QH6xAUUPnXZtTtf8ZxajicEA9uTQS1A=mo',
#   'content': 'very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.19.2',
#   'at': datetime.datetime(2024, 7, 28, 9, 37, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.19.2'},
#  {'reviewId': '2371c607-90b3-456a-a328-fb78cadd755b',
#   'userName': 'Leboea Joseph Mafereka',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJBONd_1X0unshi-gGBWRusNUZn4j7HAAW-pwqFpHg9eYFJyw=mo',
#   'content': 'Very good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 24, 18, 2, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': '93a68b34-ac53-42bd-985f-c23dc04a71bd',
#   'userName': 'Kgomotso Dinah Matlhoko',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLLYa-b9f0vOUGKOO-Ure14ZrI_kL2HxiyRRMx1NrAoujOXpg=mo',
#   'content': 'It is I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 7, 23, 18, 21, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '9a5eb0c8-3d96-4623-95b0-3c074aa8163d',
#   'userName': 'Theola Murch',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWZfc8KeWJCNhjR7_aTGM9-dG871FCRm4pcGsJgTfjiZpixFJ1B',
#   'content': "No longer see chats in my area, no more ask my street, so I can't see if anyone else has a problem with electricity!",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 22, 16, 52, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': '0f16b66e-5e5f-49ad-a2a7-fb250f9ff487',
#   'userName': 'NLT T (Nats)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVevA-M0fPpl5wJtMohuV0WTlOqfB0cK4ve5WQVhG6PCKCo-rlC',
#   'content': 'This App went fm brilliant to terrible. Very irritating is the nonsensical chats that have zero to do with LSing. Job searches! How to end a relationship! Etc etc',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 22, 11, 26, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': 'dbde1924-f105-4fcd-9903-382fb1e6025d',
#   'userName': 'EDGAR Kgopa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJbExJWFcrJO5L0YPwhiveEbOEk6pc8QcCOLF7_02F-Vz1oEw=mo',
#   'content': 'exceptional app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 7, 22, 9, 49, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'cacecfe2-0cde-40ca-a40e-e0429ef7b23a',
#   'userName': 'Jacolene Benadé',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXC_OejtHOYO5h6jxLilTMGDWyUv4ZV1xHaMhuLUoeIlc7F1biE',
#   'content': 'Should be pre-installed in every South African phone.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.1',
#   'at': datetime.datetime(2024, 7, 22, 8, 20, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.1'},
#  {'reviewId': '5a571a54-832b-46e0-9dee-2d26aa9d1c15',
#   'userName': 'sillah thandi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWWHhzhRfJ3CzpK4BNNKaynYjc4R39Hf-hiwMCa9_d7QhVq_RxlPg',
#   'content': "load shedding has started again, now they call it reduction and this app is failing to notify me. heck, is still saying no load shedding in my area but as I'm typing now I'm sitting in the dark.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.25.2',
#   'at': datetime.datetime(2024, 7, 19, 17, 53, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.25.2'},
#  {'reviewId': '75c245fd-1139-4496-b733-939eab06abbb',
#   'userName': 'Solie Masinga',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJYGL9nmxrlmX5zUGVtQjKC67LKxPiNA29nen2to3yMWsHxYw=mo',
#   'content': 'Somerset trust',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.23.11',
#   'at': datetime.datetime(2024, 7, 18, 14, 56, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.23.11'},
#  {'reviewId': 'd467b2ef-5ab6-4b8f-9a0c-e432036a8db9',
#   'userName': 'Thapelo Chilwane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUI0MNFaHR1UxkKeO59WQC4_mI1q2eA1jHxJi8zYXxE9Rekif60',
#   'content': "Loadsheding is back but there's no update on the app, what's happening?",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 18, 6, 36, 32),
#   'replyContent': "Hi Thapelo! It's load reduction not loadshedding ... We're experimenting with getting the outages into the app. Have you tried ESP Chats?",
#   'repliedAt': datetime.datetime(2024, 7, 18, 6, 38, 55),
#   'appVersion': '4.1.0'},
#  {'reviewId': '4d9eb1fa-1ff2-4dff-a451-557813fb9e67',
#   'userName': 'Charles',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKJ720Zu554962aAkSPrEkpkVCh-8xeXLLzL52jBrdUke2OMw=mo',
#   'content': "This App needs to be updated. We now get Load Reduction and Load Limiting. So there's no warning when it happens.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 15, 21, 48, 44),
#   'replyContent': "Thanks Charles! We're working on it 😅 have you tried ESP Chats?",
#   'repliedAt': datetime.datetime(2024, 7, 18, 6, 40, 56),
#   'appVersion': '4.1.0'},
#  {'reviewId': 'd585f7e0-e787-4702-b886-761545dcc2d0',
#   'userName': 'Phillipina Enkeld',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVgGJdEWNjPTID0AyADsuP161dcFcM4xO4NAiTrQisHW8BD32g',
#   'content': 'I like 😍❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 15, 14, 56, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.0'},
#  {'reviewId': 'f9b4456c-0ad6-4b64-97f4-5967f201499c',
#   'userName': 'Nd Qaku',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLzm3BsUs_c3IWGheGMdNP4oo73gCbu0v0WC3wZV7Uo6J86kA=mo',
#   'content': 'What it shows us in the schedule is true',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 7, 14, 19, 27, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '90276ff0-ac67-4a2c-bb00-8f7f6b2d37f2',
#   'userName': 'Trojan Proxy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXhs-hQymTvHn8VRKyUMor-k3RMWKCtzf05uB6yz7bk7KaUhvwD',
#   'content': 'Since new update the user interface is terrible. Have now no idea where to find any categories. This app is going in the wrong direction.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 14, 16, 55, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.0'},
#  {'reviewId': 'fc4da136-acb4-44f9-b663-95eb881b5586',
#   'userName': 'Vunene Risiva',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXiw0tr2SzeEJzqBnsYMepb9aNxcA64IR27MKs0hlvpHxckYPoN',
#   'content': 'This new update is TRASH. It literally deletes any issue you report.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 13, 10, 10, 27),
#   'replyContent': "Hi Vuvene! Can you send some more details to support@esp.info? If your posts are being deleted it's because they're being marked as spam or violating the terms.",
#   'repliedAt': datetime.datetime(2024, 7, 18, 6, 43, 25),
#   'appVersion': '4.1.0'},
#  {'reviewId': '62eace85-fba0-4a79-921f-cc4778b9f234',
#   'userName': 'Neo Nelly',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ6ltIdObG8WLuNacoqEAn1t7vFlvG4LKQRQMCFilgH7ySD0g=mo',
#   'content': 'amazing 👏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.25.2',
#   'at': datetime.datetime(2024, 7, 11, 20, 49, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.25.2'},
#  {'reviewId': 'e80b9ae8-e85e-4239-8c55-9376ae5a72ec',
#   'userName': 'Shane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVxNP66MRM7EtjHY8jyp8mWGYUCby4E1_Jz0-HKyWxFbLq5ZZiuqg',
#   'content': 'Even without the loadshedding this app is handy. Great work. Long time user.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 11, 8, 25, 42),
#   'replyContent': "You're awesome",
#   'repliedAt': datetime.datetime(2024, 7, 11, 10, 43, 5),
#   'appVersion': '4.1.0'},
#  {'reviewId': 'a92ac10e-7ff0-440f-990a-81def670c91c',
#   'userName': 'Jacques Steyn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK_3SWLl-Q9e1IQZCE_M32hsNF_mJztjzfFyiQp5wc5DdpErA=mo',
#   'content': 'Thank you so much for your help, you guys are heroes! Please do not get discouraged! Never disband this app please! We never know when we as a comunity need te stand together and help eachother.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.1.0',
#   'at': datetime.datetime(2024, 7, 4, 22, 4, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.1.0'},
#  {'reviewId': 'b22c47fc-4ed4-4e06-a29c-5e925a419ca5',
#   'userName': 'T M',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKyqPyVFbt0kPQQCFg4RGEn-dKQgkpekbF0Wiv5szvWFkcUoQ=mo',
#   'content': 'On the ball.... Unlike Eskom Still one of the best apps ever 👍🏻',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 7, 3, 20, 2, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': 'f0f61938-40b6-45af-92ca-bc1aef7cde86',
#   'userName': 'Emmanuel nzubechukwu Obioma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVEt-5MYMKYKxIYel1nPh9T_Lv46x__Q7hgWgXREVmjMgOmab05',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 7, 3, 2, 36, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': 'c5c3801e-2b6b-490b-9651-cb84df57ed3a',
#   'userName': 'Pam Rogers',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJfqeW3UZOfy4OvQ57MJFtt0crkhvbPHps0FOPu1v1FcQes3w=mo',
#   'content': 'Great app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 30, 17, 34, 9),
#   'replyContent': "We're always working hard to improve the app. Thanks for your download and feedback.\n",
#   'repliedAt': datetime.datetime(2024, 6, 30, 17, 36, 3),
#   'appVersion': '4.0.5'},
#  {'reviewId': 'ee1bce83-229f-454d-938c-0484045f3fb8',
#   'userName': 'Thomas Ndaba',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIFwPVeZzpoS6UBRro6qvkf3wGyM4pqABbT8rzC_ixiJo2I9g=mo',
#   'content': 'Excellent',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 29, 23, 59, 9),
#   'replyContent': 'Hi, if you like the app, please give us 5 stars rating. If you have any suggestions, please let us know at support@esp.info.',
#   'repliedAt': datetime.datetime(2024, 6, 30, 6, 24, 10),
#   'appVersion': '4.0.5'},
#  {'reviewId': '68b60405-21dc-45df-8082-44cb5bf7d3ce',
#   'userName': 'Nokwakha Nyambose',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJtQFE6fa19pwM9uvJHClhjtjq5jE8BSN6FZ-XzwZpAw7qOAw=mo',
#   'content': 'Best app ever',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 29, 19, 28, 56),
#   'replyContent': 'Dear friend, we are really glad that you like our product. Your support and voice are very important to us.',
#   'repliedAt': datetime.datetime(2024, 6, 29, 20, 24, 13),
#   'appVersion': None},
#  {'reviewId': 'cf3e86ff-9437-4890-8741-3e2aa11c5fdd',
#   'userName': 'Ito Lengana',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUSpnIDfhkOx7DTzzj9_yRjmj8f5IA-L5cKu5nBuk2pzEgtCjm8',
#   'content': 'Goop app ever',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 27, 22, 53, 58),
#   'replyContent': 'Hi, thanks but if you like the app, please give us 5 stars rating. If you have any suggestions, please let us know at support@esp.info.',
#   'repliedAt': datetime.datetime(2024, 6, 27, 23, 34, 37),
#   'appVersion': '4.0.5'},
#  {'reviewId': '2584659a-5950-46f8-ae70-53556c7ffe5b',
#   'userName': 'Tobie Boshoff',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJpEMVZo_91AW2MHpOMaYVvkTd6b3paqXPAYOeq08qLF1-OaA=mo',
#   'content': 'Dit is n gemors kry dit nie afgelaai nie.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 27, 14, 50, 43),
#   'replyContent': 'Dankie Tobie',
#   'repliedAt': datetime.datetime(2024, 6, 27, 15, 4, 15),
#   'appVersion': '4.0.5'},
#  {'reviewId': '2b351190-5688-41df-ad90-9155adfeb779',
#   'userName': 'BRIAN (BigNtranstours)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVFn2wEHe9BeJ-eeXnzI1B_qB4oLGAtKq6OXg9lBVJKznDcoDnhLg',
#   'content': 'Keeps community close and busy',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 26, 20, 57, 36),
#   'replyContent': 'Let us know what we can do for 5 stars. support@esp.info',
#   'repliedAt': datetime.datetime(2024, 6, 26, 21, 47, 17),
#   'appVersion': '4.0.5'},
#  {'reviewId': '68fd21cb-234e-4ada-8e69-3e389d6d55ff',
#   'userName': 'Umar Mathir',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKV5Mp9wKztZdMHo5BAEuKFj0PdXIpQ6rVtNdkDDHKo81ioCw=mo',
#   'content': 'Horrible',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 25, 16, 23, 5),
#   'replyContent': 'Hi, could you please tell us why do you dislike our app? If you have any suggestions, please send them to support@esp.info.',
#   'repliedAt': datetime.datetime(2024, 6, 25, 16, 27, 32),
#   'appVersion': None},
#  {'reviewId': 'f44aea6a-31a8-4d4a-8124-a367ecd9161e',
#   'userName': 'Isak Bekker',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJwUi1g7YvmW5YgftxRRBgl4jOrr3ULZoE63do3Q6xCzETkhQ=mo',
#   'content': 'What a great app! Especially love the way you have improvised since less to no loadshedding by improving local outrages 👍🏻 Well done!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 24, 18, 46, 57),
#   'replyContent': "Thank you. That's exactly it",
#   'repliedAt': datetime.datetime(2024, 6, 24, 18, 59, 44),
#   'appVersion': '4.0.5'},
#  {'reviewId': 'c6bfd039-2950-43ce-bc76-db075aec19de',
#   'userName': 'Brian Havinga',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3zzjEWXLmGoDSajLKMq-qLNJ5UJBi3KDQPZrZEQB-LxAZsNwV',
#   'content': "I've been a member for many (6+) years and have had great chat times in the past . This has always been a fantastic app that one can rely on and trust 👍 😀 👌",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 24, 16, 29, 4),
#   'replyContent': 'Thank you so much for your review!',
#   'repliedAt': datetime.datetime(2024, 6, 24, 16, 49, 15),
#   'appVersion': '4.0.5'},
#  {'reviewId': 'fcf62971-3073-4e26-9740-8ab0d48f3bc0',
#   'userName': 'Abigail Fede',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJsf-hTKKAnF2qvgsMlJT_gx4AnGNIK9cyasqsPHXjnt_LEIg=mo',
#   'content': 'Good experience',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 24, 13, 17, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': 'e4c44521-0e8d-4046-8605-729446a11476',
#   'userName': 'Joselin Kinsey Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLPEdAKr_Ta8G6KKNLlwIU5YR1oYin55Fn3eJMqYCLiHIANpA=mo',
#   'content': '𝓑𝓮𝓬𝓪𝓾𝓼𝓮,𝓲𝓽 𝓽𝓮𝓵𝓵𝓼 𝓾𝓼 𝔀𝓱𝓮𝓷 𝔀𝓮 𝓱𝓪𝓿𝓮 𝓵𝓸𝓪𝓭𝓼𝓱𝓮𝓭𝓭𝓲𝓷𝓰 𝓪𝓷𝓭 𝓱𝓪𝓿𝓮 𝓷𝓸 𝔀𝓪𝓽𝓮𝓻 𝓲𝓷 𝓽𝓱𝓮 𝓪𝓻𝓮𝓪𝓼',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 23, 21, 55, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': '319c6502-0841-46ee-bcc0-86768d77f81b',
#   'userName': 'Clayton Joseph',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX_tY4cSuNLqSTgKiNa_bqrnHNlthbRUlibfeFExIaxiNK1L70SZA',
#   'content': 'Why restrict Chat? AskMyStreet: Chat has been integrated with your area. Now you can easily post to your area specifically. I want to see chats from wider area -> how do I do this now?',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 22, 8, 3, 38),
#   'replyContent': "Hey, we're checking this. for now just add the areas nearby.",
#   'repliedAt': datetime.datetime(2024, 6, 22, 14, 38, 46),
#   'appVersion': '4.0.5'},
#  {'reviewId': '65f9ef8b-cfb9-4210-9088-eb732c491e75',
#   'userName': 'Mzie KING',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIygxzY6CxCp74y1-Ho8rmhYFUSeiayO2xH2YTkLCNpzJ6_lQ=mo',
#   'content': 'Best loadshedding app ever',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 21, 19, 10, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': '7e6a746e-2dcc-47d1-bffe-2f6c253af0ec',
#   'userName': 'Silentcrow21',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXhRHVvErLPEApZxYvzP7Cbxfhj2HkhIh8wH86hcagL9Ssg2OYq',
#   'content': "Over and above, honestly. It's one of the top three apps I've used in the past half a decade. And they keep developing and making it better.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 20, 12, 12, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': '0c701857-35ad-4058-b5df-bf54cd5bf6b1',
#   'userName': 'Bruno Ambrogio',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWmopedGIu_a9PWRTLNI7xN70piowk0-lpsoLO1ClCwKqPWU4w',
#   'content': 'The old one was much better...now much less feedback from people in the suburb...',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 19, 21, 32, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': 'c4ee347c-706c-4935-82ce-48e28f4085b9',
#   'userName': 'Kotie Steenkamp',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXNhb2iHFyIO8snxxSQMQVqsCTWDoUxlsyW0gFQjbPrFXw8Dsk',
#   'content': '💕 love the new look',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 19, 14, 20, 42),
#   'replyContent': 'Thank you!',
#   'repliedAt': datetime.datetime(2024, 6, 19, 14, 33, 43),
#   'appVersion': '4.0.5'},
#  {'reviewId': '26ac408c-c051-49cd-9f63-21331c4055c5',
#   'userName': 'Elmari du Toit',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUg49XyehZQp-0m7SqGQyFFyEpF__k7A0wJHSLRRvnt_gZK2Tb5rw',
#   'content': 'ESP shows no loadshedding. Did they not update u guys that loadshedding is now called load reduction...pls update the app with the new shedules',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.5',
#   'at': datetime.datetime(2024, 6, 18, 16, 23, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.5'},
#  {'reviewId': 'e210c1e5-7581-40f8-8fde-3307cafe0902',
#   'userName': 'Lizette',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUgRuhymboi80AF-fPwgVgJsbawiG0nPmKSSoiitT2VR7DmEncI',
#   'content': 'keeps me updated on load shedding has not been wrong yet',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '4.0.2',
#   'at': datetime.datetime(2024, 6, 18, 8, 11, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '4.0.2'},
#  {'reviewId': 'cf5ac216-ef57-4ae1-9fce-e103c1cfb6cd',
#   'userName': 'Manunu Buwa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJN4BnWTSmaRmtAm5d9YxFGZMB3_JLsNAD_GYnxGuUziNLj6Q=mo',
#   'content': 'Good',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.27.3',
#   'at': datetime.datetime(2024, 6, 17, 8, 0, 35),
#   'replyContent': 'Only 4 stars? 🤩',
#   'repliedAt': datetime.datetime(2024, 6, 17, 8, 13, 7),
#   'appVersion': '3.27.3'},
#  {'reviewId': '0f88bf0c-7b95-4ad6-afe7-87c8cf7cec51',
#   'userName': 'Nomvuyiso Tiyana',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL8OxSwiVTlsBfcgWNXhue-KbicQKSmUGZKcz_bOTlZVpRU2w=mo',
#   'content': 'Wanna know about load shedding',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 6, 14, 16, 47, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '96141469-b6ed-4a50-a333-b497d1b082d8',
#   'userName': 'Elizabeth Muramani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIteY2pmfn8V4dHw8aei56V8rQF2TmbaK5Fny9YvqC13V2yqg=mo',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.25.2',
#   'at': datetime.datetime(2024, 6, 14, 8, 43, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.25.2'},
#  {'reviewId': 'b5113d66-facd-471f-98ca-4624dafd0e90',
#   'userName': 'Peter',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKZo2c2Z-G5sbSUUjpeonYLX1hq9Rdx2HdJrFFlyfZaBGkWMA=mo',
#   'content': 'Helps when the schedule is right',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 14, 7, 55, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '5ac76280-61bc-41f8-ad45-8ae6766e3d2b',
#   'userName': 'Basil Malatse',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVwXu6j-1jBJ6o5RSnRKtUHnyHzy8qAIHYye_GVlGdsQb58bij-',
#   'content': "5 star to fix the misconception from everyone that thinks this app is in charge of the loadshedding 😁. This app is just a messenger so don't shoot it. App works great with the alerts.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.27.3',
#   'at': datetime.datetime(2024, 6, 13, 17, 53, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.27.3'},
#  {'reviewId': '2e7ce5cd-e34b-4c97-a7e7-bb0a361674f5',
#   'userName': 'DON WESTLY',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLNpKT3L8srhb-x9GYRLfg-h-O40sW6M-YlPG4aQIwOUOBTSA=mo',
#   'content': 'Nice app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 13, 15, 27, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '15dbedb2-4a81-4ad2-ba45-bf0fcf7148df',
#   'userName': 'Janine Stanfliet',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLtb5kjQoYw4KD8ifq3KvHq-YZ7pCYPWzu71e506izqmHy4jA=mo',
#   'content': "Most accurate and in sync with the area schedules and appropriate push notifications. I also quite enjoy the quirky comments, adding a fun twist to the already gloomy purposed of the app. Can't go wrong with downloading this app to track loadshedding of numerous areas that you frequent.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 13, 14, 51, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'bb30a8d0-435c-40b9-8c88-36018ede1baa',
#   'userName': 'Chumisa Dyani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXAAGFooeqrh7yiiQsAJ0QEzBWIfqF-m4FR26Fg2Oxh1Y8EC4SK',
#   'content': '100%fast',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 12, 10, 44, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'e029c160-2752-4866-b489-f98ce742d704',
#   'userName': 'Tryphina Maseko',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJMgZc-LPc1J-e9lY0cTV8gLmbibjfkac0-QCeJzcBynPrng=mo',
#   'content': 'It is user friendly.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 10, 13, 30, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'd562841c-9d3c-4525-886d-2a46d4ea33c7',
#   'userName': 'Charlotte deKlerk',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKjW_4gbdd4m0D-JG8Ej9h18VZddUyxt5qQ1iPd75Zp-mt2tg=mo',
#   'content': 'Yes you can give the load shedding schedules. But what bothers me is can you give the load reduction schedules. Because load reduction is different from load shedding.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 6, 10, 9, 4, 16),
#   'replyContent': 'Already loaded to the app for affected areas. - Jeff',
#   'repliedAt': datetime.datetime(2024, 6, 10, 9, 26, 6),
#   'appVersion': '3.28.2'},
#  {'reviewId': '8b93bf51-5e6d-446d-aba4-0dae31210e52',
#   'userName': 'Renee Alcock',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWJwEo_WMjNVeaaph1Am5eT6va3Af7_HyRTRiqNyR0qm-urlZnE',
#   'content': 'This app is so useful',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 6, 5, 18, 22, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '3935a9fd-0959-42b0-a7c6-d5d2a7ad0e0f',
#   'userName': 'Nothabo Nkiwane',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLlnS9LOBg6tnJfuRoFqQM_1hZ0CCEyb7Cxg7GOEqTwaStVYA=mo',
#   'content': 'this is a very accurate app 🥰',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.24.3',
#   'at': datetime.datetime(2024, 6, 5, 12, 47, 27),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.24.3'},
#  {'reviewId': 'b7f76119-d3e5-41b2-95f5-139e6b4cff77',
#   'userName': 'Vusi Dlamini',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIrOLvr9g296dNUtgndj71h5mO0eNcTnNmovSZkljO_Xy1wOQ=mo',
#   'content': 'Nice app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.27.3',
#   'at': datetime.datetime(2024, 6, 4, 17, 49, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.27.3'},
#  {'reviewId': '50d77810-ba8b-4568-8c77-ecbc59b8256a',
#   'userName': 'Mboneni Neluvhola',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJDS8jasyhajMDQMKbBLpI0pV0WDctIuL5MCKojUnEjjY5NVw=mo',
#   'content': 'Very accurate nd informative',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2024, 6, 2, 18, 51, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'd9f2b3e0-e902-44af-a070-88341c1f4907',
#   'userName': 'C Hayes',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLT93odgZCjcXyrqMX6CRsQi7ZJ5BYdzgLtZm6mBpQZ9SY8miw=mo',
#   'content': 'This app is for electricity, water and municipal issues.....not a "looking for job".... so irritating......this is not a emloyment or social platform....',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 6, 2, 17, 45, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '101c345c-93b4-4c36-90ed-05e67930660d',
#   'userName': 'Soleil Smit',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIBA9xCesSldNPibAF-77TfzweSQwduP5_Nrw_lf5Zh1YYFMA=mo',
#   'content': "There's loadshedding at the moment and it says no loadshedding",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.17.3',
#   'at': datetime.datetime(2024, 5, 31, 18, 4, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.17.3'},
#  {'reviewId': '5a68cfda-609c-4266-855e-51d0e0e88024',
#   'userName': 'Thlalefo Makahane',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUvi9vWyBuLhQKweu0hQB0P02_a4FmsY0ZWuYX2NG9kPyKQjIh6',
#   'content': 'This us a good app loadshedding as it tells the stage and what time the loadshedding starts and ends ☆☆☆☆☆ for this team',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.16.12',
#   'at': datetime.datetime(2024, 5, 30, 11, 42, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.16.12'},
#  {'reviewId': 'd21c66df-24fd-4b53-a1a5-e3524994c7a1',
#   'userName': 'Danjo Olivier',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJDCmLjtfFSKdbXKl2YaVEjw8Bf4xa8VMTm3jniWgSjHEs_4Q=mo',
#   'content': 'Always correct and love the fact that you can add as much areas as you want',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 30, 10, 3, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '20fce319-74e0-4d14-bdb9-44e3b369a686',
#   'userName': 'Music world',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUXAf4fERN5YmxeaPBdXtSSkLLGk2w-7S0BZQxUidEDO_xwpMjY',
#   'content': "I downloaded this app for load shedding, but instead get spammed with unrelated nonsense if I wanted to know about voting ect I would have went to the a source specifically ment for that. So please bring a option to disable the other nonsense if one isn't interested",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 29, 20, 11, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '0772056e-7ed4-4d40-9307-a94bd7bde13c',
#   'userName': 'Assassin Assassin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL7l7QXTYY-1xFekxDXM767J5bqAZU_jzvbQg5U9J5TbC5byQ=mo',
#   'content': "The most accurate App. I get notifications in time even when there are small changes. It makes life easier I'm able to plan things ahead",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.27.3',
#   'at': datetime.datetime(2024, 5, 29, 9, 12, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.27.3'},
#  {'reviewId': '73fa319f-c305-4aba-bc7f-473f5416360f',
#   'userName': 'Zee',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVPxpKs80VzLDBQm5YqxxUcvDcvGv6LNxU3Muct8RnUgaywZ0o',
#   'content': 'The name is just slay',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 27, 19, 17, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': 'af917914-fda3-4acd-b2e2-161c03a7cfb8',
#   'userName': 'Pieter Harmse',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX_VR-9izKYCmWw2bIc6YZbZvSMfJFlw_DIz78l1ueuUSzwwFqd',
#   'content': 'Still doing it, now with elections, esp se P! One star for using the loadshedding notification to promote a sport event. This is a loadshedding app, not a sport/news/reminder app. I get enough spam every day, thank you.',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 27, 13, 20, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': 'dd3f3384-4aca-4e78-969c-d0eeabb99872',
#   'userName': 'slaser 43',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW6ebLZcHnhk4PgbboosH2487FGfaiLcOQlzIKEccWNPIdoDXc',
#   'content': 'very useful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 22, 22, 29, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': 'd0417acd-b876-446d-930d-79a9ddecf4ab',
#   'userName': "Dominic d'Hotman",
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLzW_8sq8Q6WWlTsGdqrSCb36gMC0Bz6kESOpKLVJCGWsSYlA=mo',
#   'content': 'Changed this to one star. For some reason nothing I post on ask my street is going through. Also whenever I go to report "no electricity" or "no water" in my area I\'m met with a blank screen. Edit: Issue resolved. Thank you for your reply.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 21, 17, 59, 49),
#   'replyContent': 'Jeff made some "performance tweaks" and, uhm, broke something. All sorted now! \\o/ Try again?',
#   'repliedAt': datetime.datetime(2024, 3, 10, 21, 2, 27),
#   'appVersion': '3.28.2'},
#  {'reviewId': 'f463c18b-8d41-4b01-aad9-5c0e3f0d0b71',
#   'userName': 'Stuart Van Der Merwe',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWxOyH-RKcNy3KL1xnFNub31BDtu8wgP-JBB-EFkLrhZMYLtVze',
#   'content': 'Remove Ads from the app.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 21, 16, 27, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': 'd858323e-ec83-4c17-9b9e-1ec36687cfee',
#   'userName': 'Philadi Malajane',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI6CjtOfOZNlkOvtCmBLhYY-Slm7tOwIk_V7VM7cip8l4ZGSQ=mo',
#   'content': '💯',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 19, 19, 0, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': '38c44dfb-7376-480c-90b2-284a022ceb7b',
#   'userName': 'Tristan Coates',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXLYMXSbptHi7y3zT4xaV8cNGUkyBy8n86oqLOCngRQR0MShUnW',
#   'content': "this app is amazing. it's super useful and it really helped us through the loadshedding struggles. I'm also glad they dont just cover loadshedding.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.22.5',
#   'at': datetime.datetime(2024, 5, 17, 18, 5, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.22.5'},
#  {'reviewId': '9ed7a655-9e4c-46bc-8f13-13e076525722',
#   'userName': 'Nthabiseng Chabeli-Hlophe (Gogo LoBovu)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXuZzlIg_d3Qj70a9kGYajIQlxs3Bkb8PJj1G8uIy3KcphgduK6',
#   'content': "App always asks me to review my location settings even though I have given all permissions. I'm unable to read messages when I open the App even though a message alert popped up on my screen.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 17, 4, 47, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '3.28.2'},
#  {'reviewId': 'f656e117-9c47-4665-b1bd-9682268ceb00',
#   'userName': 'Tyrone Brecker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWV6d3HA5YldfjAGbik2kYcPqasTyEvSwdQJwzB1tc8SQ_DATz2',
#   'content': "Now that loadshedding is gone for a month or 2 the news section just doesn't work. This app is truly amazing. It shows you the level of incompetence of the dev team, eskom themselves, and the ANC. They all share a collective of 3 brain cells.",
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '3.28.2',
#   'at': datetime.datetime(2024, 5, 15, 14, 40, 13),
#   'replyContent': "Our next update will show `Bug fixes and performance improvements` just for you 😅. Please email support@esp.info and we'll fix those bugs ASAP!",
#   'repliedAt': datetime.datetime(2024, 2, 21, 20, 20, 25),
#   'appVersion': '3.28.2'}]

# %%
reviews = [result[i]['content'] for i in range(100)]

# %%
reviews

# %%
reviews_df=pd.DataFrame(reviews)

# %%
reviews_df

# %%
import re
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

reviews_df['cleaned_data'] = reviews_df[0].apply(clean_data)

# %%
reviews_df.head()

# %%
def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

reviews_df['cleaned_data'] = reviews_df['cleaned_data'].apply(drop_numbers)

# %%
reviews_df

# %%
import nltk
nltk.download('punkt')
def lower_case(text):
    text_words = word_tokenize(text)
    text_words_lower = [x.lower() for x in text_words]
    return ' '.join(text_words_lower)

reviews_df['cleaned_data'] = reviews_df['cleaned_data'].apply(lower_case)

# %%
nltk.download('wordnet')

# %%
nltk.download('omw-1.4')

# %%
lemmatizer = WordNetLemmatizer()
def lemmatise(text):
    text_tokens = word_tokenize(text)
    text_lemm = [lemmatizer.lemmatize(word) for word in text_tokens]
    return ' '.join(text_lemm)

reviews_df['cleaned_data'] = reviews_df['cleaned_data'].apply(lemmatise)

# %%
def remove_stopword(text):
    text_tokens = word_tokenize(text)
    tokens = [word for word in text_tokens if not word in set(stopwords.words('english'))]
    tokens_text = ' '.join(tokens)
    return tokens_text

reviews_df['cleaned_data'] = reviews_df['cleaned_data'].apply(remove_stopword)

# %%
reviews_df.head()

# %%
def get_polarity(text):
    textblob = TextBlob(str(text))
    pol = textblob.sentiment.polarity
    if(pol==0):
        return "Neutral"
    elif(pol>0 and pol<=0.3):
        return "Weakly Positive"
    elif(pol>0.3 and pol<=0.6):
        return "Positive"
    elif(pol>0.6 and pol<=1):
        return "Strongly Positive"
    elif(pol>-0.3 and pol<=0):
        return "Weakly Negative"
    elif(pol>-0.6 and pol<=-0.3):
        return "Negative"
    elif(pol>-1 and pol<=-0.6):
        return "Strongly Negative"
    
reviews_df['polarity'] = reviews_df['cleaned_data'].apply(get_polarity)

# %%
reviews_df.head()

# %%
reviews_df['polarity'].value_counts()

# %%
neutral = 0
wpositive = 0
spositive = 0
positive = 0
negative = 0
wnegative = 0
snegative = 0
polarity = 0

for i in range(0,100):
    textblob = TextBlob(str(reviews_df['cleaned_data'][i]))
    polarity+= textblob.sentiment.polarity
    pol = textblob.sentiment.polarity
    if (pol == 0):  # adding reaction of how people are reacting to find average later
        neutral += 1
    elif (pol > 0 and pol <= 0.3):
        wpositive += 1
    elif (pol > 0.3 and pol <= 0.6):
        positive += 1
    elif (pol > 0.6 and pol <= 1):
        spositive += 1
    elif (pol > -0.3 and pol <= 0):
        wnegative += 1
    elif (pol > -0.6 and pol <= -0.3):
        negative += 1
    elif (pol > -1 and pol <= -0.6):
        snegative += 1

# %%
NoOfTerms = 100
polarity = polarity / NoOfTerms
polarity

# %%
def percentage(part, whole):
    temp = 100 * float(part) / float(whole)
    return format(temp, '.2f')

# %%
positive = percentage(positive, NoOfTerms)
wpositive = percentage(wpositive, NoOfTerms)
spositive = percentage(spositive, NoOfTerms)
negative = percentage(negative, NoOfTerms)
wnegative = percentage(wnegative, NoOfTerms)
snegative = percentage(snegative, NoOfTerms)
neutral = percentage(neutral, NoOfTerms)

# %%
print("How people are reacting on " + "the load shedding app" + " by analyzing " + str(NoOfTerms) + " reviews.")
print()
print("-----------------------------------------------------------------------------------------")
print()
print("General Report: ")

if (polarity == 0):
    print("Neutral")
elif (polarity > 0 and polarity <= 0.3):
    print("Weakly Positive")
elif (polarity > 0.3 and polarity <= 0.6):
    print("Positive")
elif (polarity > 0.6 and polarity <= 1):
    print("Strongly Positive")
elif (polarity > -0.3 and polarity <= 0):
    print("Weakly Negative")
elif (polarity > -0.6 and polarity <= -0.3):
    print("Negative")
elif (polarity > -1 and polarity <= -0.6):
    print("Strongly Negative")

print()
print("------------------------------------------------------------------------------------------")
print()
print("Detailed Report: ")
print(str(positive) + "% people thought it was positive")
print(str(wpositive) + "% people thought it was weakly positive")
print(str(spositive) + "% people thought it was strongly positive")
print(str(negative) + "% people thought it was negative")
print(str(wnegative) + "% people thought it was weakly negative")
print(str(snegative) + "% people thought it was strongly negative")
print(str(neutral) + "% people thought it was neutral")

# %%
sizes = [positive, wpositive, spositive, neutral, negative, wnegative, snegative]
colors = ['yellowgreen','lightgreen','darkgreen', 'gold', 'red','lightsalmon','darkred']
labels = ['Positive [' + str(positive) + '%]', 'Weakly Positive [' + str(wpositive) + '%]',
          'Strongly Positive [' + str(spositive) + '%]', 'Neutral [' + str(neutral) + '%]',
          'Negative [' + str(negative) + '%]', 'Weakly Negative [' + str(wnegative) + '%]', 
          'Strongly Negative [' + str(snegative) + '%]']

# %%
plt.pie(sizes, labels = labels, colors = colors)
plt.legend(labels, loc="best")
plt.title('How people are reacting on ' + 'the loadshedding app' + ' by analyzing ' + str(NoOfTerms) + ' reviews.')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
data =[positive, wpositive, spositive, neutral, negative, wnegative, snegative]
index = ['Positive', 'Weakly Positive', 'Strongly Positive','Neutral','Negative','Weakly Negative','Strongly Negative']
df = pd.DataFrame(data,index,columns=['Reactions'])

# %%
print(df)

# %%
plt.pie(x=df['Reactions'],labels=index)
plt.tight_layout()
