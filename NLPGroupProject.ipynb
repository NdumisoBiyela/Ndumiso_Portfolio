# %% [markdown]
# # NLP Classifaction Project
#
# ###
#
#
# © ExploreAI 2024
#
# ---
#
# ## Table of Contents
#
# <a href=#BC> Background Context</a>
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Data Collection and Description</a>
#
# <a href=#three>3. Loading Data </a>
#
# <a href=#four>4. Data Cleaning and Filtering</a>
#
# <a href=#five>5. Exploratory Data Analysis (EDA)</a>
#
# <a href=#six>6. Modeling </a>
#
# <a href=#seven>7. Evaluation and Validation</a>
#
# <a href=#eight>8. Final Model</a>
#
# <a href=#nine>9. Conclusion and Future Work</a>
#
# <a href=#ten>10. References</a>

# %% [markdown]
# ---
#  <a id="BC"></a>
# ## **Background Context**
# <a href=#cont>Back to Table of Contents</a>
#
#
# ---

# %% [markdown]
# ---
# <a href=#one></a>
# ## **Importing Packages**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Set up the Python environment with necessary libraries and tools.
# * **Details:** List and import all the Python packages that will be used throughout the project such as Pandas for data manipulation, Matplotlib/Seaborn for visualization, scikit-learn for modeling, etc.
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from wordcloud import WordCloud
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\f5481198\Anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\f5481198\Anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\f5481198\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\Users\f5481198\Anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
# ...

# %% [markdown]
# ---
# <a href=#two></a>
# ## **Data Collection and Description**
# <a href=#cont>Back to Table of Contents</a>
#
# #### Data Description

# %% [markdown]
# ---
# <a href=#three></a>
# ## **Loading Data**
# <a href=#cont>Back to Table of Contents</a>
#
#
# ---

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.describe()
# Out:
#                                                 headlines  \
# count                                                5520
# unique                                               5512
# top     KC Mahindra Education Trust invites applicatio...
# freq                                                    2
#
#                                               description  \
# count                                                5520
# unique                                               5508
# top     For Delhi and NCR students the deadline to sub...
# freq                                                    2
#
#                                                   content  \
# count                                                5520
# unique                                               5513
# top     Grand Slam fever grips tennis fans all over th...
# freq                                                    5
#
#                                                       url   category
# ...

# %%
train_df.head()
# Out:
#                                            headlines  \
# 0  RBI revises definition of politically-exposed ...
# 1  NDTV Q2 net profit falls 57.4% to Rs 5.55 cror...
# 2  Akasa Air ‘well capitalised’, can grow much fa...
# 3  India’s current account deficit declines sharp...
# 4  States borrowing cost soars to 7.68%, highest ...
#
#                                          description  \
# 0  The central bank has also asked chairpersons a...
# 1  NDTV's consolidated revenue from operations wa...
# 2  The initial share sale will be open for public...
# 3  The current account deficit (CAD) was 3.8 per ...
# 4  The prices shot up reflecting the overall high...
#
#                                              content  \
# 0  The Reserve Bank of India (RBI) has changed th...
# 1  Broadcaster New Delhi Television Ltd on Monday...
# 2  Homegrown server maker Netweb Technologies Ind...
# 3  India’s current account deficit declined sharp...
# ...

# %% [markdown]
# ---
# <a href=#four></a>
# ## **Data Cleaning and Filtering**
# <a href=#cont>Back to Table of Contents</a>
#
# ---

# %%
train_df.isna().sum()
# Out:
# headlines      0
# description    0
# content        0
# url            0
# category       0
# dtype: int64

# %%
train_df['url'].unique()
# Out:
# array(['https://indianexpress.com/article/business/banking-and-finance/rbi-revises-politically-exposed-persons-kyc-9096600/',
#        'https://indianexpress.com/article/business/companies/ndtv-q2-net-profit-falls-lower-revenue-higher-expenses-8996212/',
#        'https://indianexpress.com/article/business/market/netweb-technologies-ipo-price-band-rs-475-500-per-share-8833096/',
#        ...,
#        'https://indianexpress.com/article/technology/tech-news-technology/amazon-ad-on-google-search-redirects-users-to-microsoft-tech-support-scam-8903558/',
#        'https://indianexpress.com/article/technology/science/elon-musk-twitter-x-valuation-drops-19-billion-9007542/',
#        'https://indianexpress.com/article/technology/tech-news-technology/ios-17-point-2-update-new-features-supported-iphones-9064432/'],
#       dtype=object)

# %%
# Check for duplicate rows
duplicates = train_df.duplicated().sum()

print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
##Removing Stopwords
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
def clean_text(text):
    text = text.strip() ##Removing leading and trailing spaces
    text = re.sub(r'\d+', '', text) ##Removing numbers
    text = re.sub(r'[^\w\s]', '', text)  # Removing special characters
    text = text.translate(str.maketrans('', '', string.punctuation)) ##Removing punctuation
    text = text.lower()  ##Converting text to lowercase
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)  # Tokenizing text
    tokens = [word for word in tokens if word not in stop_words]  # Removing stopwords
    lemmatizer = WordNetLemmatizer()  # Lemmatizing text
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)

def clean_dataframe(df):
    for column in df.columns:
        df[column] = df[column].astype(str).apply(clean_text)
    return df
train_cleaned = clean_dataframe(train_df)
test_cleaned = clean_dataframe(test_df)
# Out:
# c:\Users\f5481198\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 2.0.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 ##Removing Stopwords
# ----> 2 import nltk
#       3 import string
#       4 from nltk.corpus import stopwords
#
# File c:\Users\f5481198\Anaconda3\lib\site-packages\nltk\__init__.py:132, in <module>
#     124     subprocess.Popen = _fake_Popen
#     126 ###########################################################
#     127 # TOP-LEVEL MODULES
#     128 ###########################################################
#     129
#     130 # Import top-level functionality into top-level namespace
# --> 132 from nltk.collocations import *
# ...

# %%
train_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 train_cleaned.head()
#
# NameError: name 'train_cleaned' is not defined

# %%
test_cleaned.head()
# Out:
#                                            headlines  \
# 0  nlc india win contract power supply rajasthan ...
# 1  sbi clerk prelim exam date announced admit car...
# 2  golden globe michelle yeoh ferrell angela bass...
# 3             oneplus nord r part new price cut here
# 4  adani family partner used opaque fund invest s...
#
#                                          description  \
# 0  stateowned firm nlc india ltd nlcil monday sai...
# 1  sbi clerk prelim exam sbi clerk prelim exam te...
# 2  barbie top nominee year followed closely oppen...
# 3       new deal make oneplus nord easy purchase r k
# 4  citing review file multiple tax haven internal...
#
#                                              content  \
# 0  stateowned firm nlc india ltd nlcil monday sai...
# 1  sbi clerk prelim exam state bank indian sbi an...
# 2  michelle yeoh ferrell angela bassett amanda se...
# 3  review oneplus nord g praised balanced combina...
# ...

# %% [markdown]
# ---
# <a href=#five></a>
# ## **Exploratory Data Analysis (EDA)**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Explore and visualize the data to uncover patterns, trends, and relationships.
# * **Details:** Use statistics and visualizations to explore the data. This may include histograms, box plots, scatter plots, and correlation matrices. Discuss any significant findings.
# ---

# %%
sns.set(style="whitegrid")

# Plotting the data
plt.figure(figsize=(20, 12))
sns.countplot(x='category', data=train_df)

# Adding titles and labels
plt.title('Countplot for Category Column')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.set(style="whitegrid")

# Plotting the data
plt.figure(figsize=(20, 12))
sns.countplot(x='category', data=test_df)

# Adding titles and labels
plt.title('Countplot for Category Column')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from wordcloud import WordCloud
text = " ".join(review for review in train_df.content)  # Combining all text data into a single string
font_path = 'calibri.ttf' #Font path
wordcloud = WordCloud(width=1200, height=800, background_color='white').generate(text) # Generating the word cloud
# Displaying the word cloud
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#from sklearn.feature_extraction.text
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
count_vectorizer = CountVectorizer()
content=train_cleaned['content']
vectorizer = CountVectorizer()  # Create the CountVectorizer object and fit it to your text data
content =vectorizer.fit_transform(content)  
feature_names = vectorizer.get_feature_names_out() # Get feature names (words)
dense_matrix = content.toarray()  # Convert the sparse matrix to a dense matrix
df_bow = pd.DataFrame(dense_matrix, columns=feature_names)  # Create a DataFrame

# %%
word_counts = df_bow.sum(axis=0) # Sum the counts of each word
word_counts_df = pd.DataFrame(word_counts, columns=['count']) # Convert to a DataFrame for easier plotting
word_counts_df = word_counts_df.sort_values(by='count', ascending=False) # Sort the DataFrame by count
top_n = 20 # Adjust this number to show more or fewer words
plt.figure(figsize=(10, 6))
sns.barplot(x=word_counts_df.index[:top_n], y=word_counts_df['count'][:top_n])
plt.title('Top Words by Frequency')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
# <a href=#six></a>
# ## **Modeling**
# <a href=#cont>Back to Table of Contents</a>
#
# ---

# %%
X_train = train_cleaned['content']
X_test = test_cleaned['content']
y_train = train_cleaned['category']
y_test = test_cleaned['category']

# %%
##Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train= le.fit_transform(y_train)
y_test= le.fit_transform(y_test)

# %%
##Initialize Vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
count_vectorizer = CountVectorizer()
tfidf_vectorizer = TfidfVectorizer()

# %%
# Fit and transform training data with vectorizers
X_train = tfidf_vectorizer.fit_transform(X_train)
X_test = tfidf_vectorizer.transform(X_test)

# %%
X_train
# Out:
# <5520x37585 sparse matrix of type '<class 'numpy.float64'>'
# 	with 487506 stored elements in Compressed Sparse Row format>

# %%
X_test
# Out:
# <2000x37585 sparse matrix of type '<class 'numpy.float64'>'
# 	with 176962 stored elements in Compressed Sparse Row format>

# %%
##Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
RFC_classifier= RandomForestClassifier(random_state=0, n_estimators =100, criterion ='entropy')
model= RFC_classifier.fit(X_train,y_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score,recall_score
from sklearn.metrics import classification_report, accuracy_score
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
weighted_precision = precision_score(y_test, y_pred, average='weighted')
weighted_recall = recall_score(y_test, y_pred, average='weighted')
weighted_f1 = f1_score(y_test, y_pred, average='weighted')
print(classification_report(y_test, y_pred))
model_results = pd.DataFrame([['Random Forest Classifier', acc, weighted_precision, weighted_recall, weighted_f1]],
               columns = ['Model', 'Accuracy', 'Weighted-averaged precision', 'Weighted-averaged recall', 'Weighted-averaged f1_score'])
results= model_results
model_results
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       400
#            1       0.95      0.99      0.97       400
#            2       1.00      0.93      0.96       400
#            3       0.99      0.93      0.96       400
#            4       0.86      0.95      0.90       400
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#                       Model  Accuracy  Weighted-averaged precision  \
# 0  Random Forest Classifier    0.9455                     0.948831
#
#    Weighted-averaged recall  Weighted-averaged f1_score
# 0                    0.9455                    0.946105

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Multiclass Classification')
plt.show()

# %%
##Support Vector Machine
from sklearn.svm import SVC
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predSVC = svm_model.predict(X_test)
acc = accuracy_score(y_test, y_predSVC)
weighted_precision = precision_score(y_test, y_predSVC, average='weighted')
weighted_recall = recall_score(y_test, y_predSVC, average='weighted')
weighted_f1 = f1_score(y_test, y_predSVC, average='weighted')
print(classification_report(y_test, y_predSVC))
model_results = pd.DataFrame([['SVC(linear)', acc, weighted_precision, weighted_recall, weighted_f1]],
               columns = ['Model','Accuracy', 'Weighted-averaged precision', 'Weighted-averaged recall', 'Weighted-averaged f1_score'])
results = results.append(model_results, ignore_index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       400
#            1       0.99      0.98      0.99       400
#            2       0.99      0.99      0.99       400
#            3       0.99      0.98      0.99       400
#            4       0.94      0.97      0.96       400
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.98      0.98      2000
# weighted avg       0.98      0.98      0.98      2000
# C:\Users\f5481198\AppData\Local\Temp\ipykernel_13620\3976141826.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index = True)

# %%
results
# Out:
#                       Model  Accuracy  Weighted-averaged precision  \
# 0  Random Forest Classifier    0.9455                     0.948831
# 1               SVC(linear)    0.9795                     0.979803
#
#    Weighted-averaged recall  Weighted-averaged f1_score
# 0                    0.9455                    0.946105
# 1                    0.9795                    0.979573

# %%
cm = confusion_matrix(y_test, y_predSVC)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Multiclass Classification')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predKNN = knn_model.predict(X_test)
acc = accuracy_score(y_test, y_predKNN)
weighted_precision = precision_score(y_test, y_predKNN, average='weighted')
weighted_recall = recall_score(y_test, y_predKNN, average='weighted')
weighted_f1 = f1_score(y_test, y_predKNN, average='weighted')
print(classification_report(y_test, y_predKNN))
model_results = pd.DataFrame([['KNN', acc, weighted_precision, weighted_recall, weighted_f1]],
               columns = ['Model','Accuracy', 'Weighted-averaged precision', 'Weighted-averaged recall', 'Weighted-averaged f1_score'])
results = results.append(model_results, ignore_index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       400
#            1       0.95      0.99      0.97       400
#            2       0.98      0.98      0.98       400
#            3       1.00      0.94      0.97       400
#            4       0.94      0.95      0.94       400
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
# C:\Users\f5481198\AppData\Local\Temp\ipykernel_13620\3584671534.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index = True)

# %%
results
# Out:
#                       Model  Accuracy  Weighted-averaged precision  \
# 0  Random Forest Classifier    0.9455                     0.948831
# 1               SVC(linear)    0.9795                     0.979803
# 2                       KNN    0.9625                     0.963096
#
#    Weighted-averaged recall  Weighted-averaged f1_score
# 0                    0.9455                    0.946105
# 1                    0.9795                    0.979573
# 2                    0.9625                    0.962509

# %%
cm = confusion_matrix(y_test, y_predKNN)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Multiclass Classification')
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_predNB = nb_model.predict(X_test)
acc = accuracy_score(y_test, y_predNB)
weighted_precision = precision_score(y_test, y_predNB, average='weighted')
weighted_recall = recall_score(y_test, y_predNB, average='weighted')
weighted_f1 = f1_score(y_test, y_predNB, average='weighted')
print(classification_report(y_test, y_predNB))
model_results = pd.DataFrame([['Naive Bayers', acc, weighted_precision, weighted_recall, weighted_f1]],
               columns = ['Model','Accuracy', 'Weighted-averaged precision', 'Weighted-averaged recall', 'Weighted-averaged f1_score'])
results = results.append(model_results, ignore_index = True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       400
#            1       0.95      0.99      0.97       400
#            2       0.96      0.98      0.97       400
#            3       1.00      0.90      0.95       400
#            4       0.91      0.97      0.94       400
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
# C:\Users\f5481198\AppData\Local\Temp\ipykernel_13620\430444758.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index = True)

# %%
results
# Out:
#                       Model  Accuracy  Weighted-averaged precision  \
# 0  Random Forest Classifier    0.9455                     0.948831
# 1               SVC(linear)    0.9795                     0.979803
# 2                       KNN    0.9625                     0.963096
# 3              Naive Bayers    0.9565                     0.958196
#
#    Weighted-averaged recall  Weighted-averaged f1_score
# 0                    0.9455                    0.946105
# 1                    0.9795                    0.979573
# 2                    0.9625                    0.962509
# 3                    0.9565                    0.956421

# %%
cm = confusion_matrix(y_test, y_predNB)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Multiclass Classification')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'linear']
}

# Initialize GridSearchCV
grid_search = GridSearchCV(svm_model, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best Parameters: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Score: 0.9817028985507246

# %%
# Use the best estimator to make predictions
SVCbest_model = grid_search.best_estimator_
y_predSVC = SVCbest_model.predict(X_test)
# Evaluate the model
print(classification_report(y_test, y_predSVC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       400
#            1       0.99      0.98      0.99       400
#            2       1.00      0.99      0.99       400
#            3       0.99      0.98      0.99       400
#            4       0.94      0.97      0.96       400
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.98      0.98      2000
# weighted avg       0.98      0.98      0.98      2000

# %% [markdown]
# ---
# <a href=#seven></a>
# ## **Evaluation and Validation**
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# ---
# <a href=#eight></a>
# ## **Final Model**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Present the final model and its performance.
# * **Details:** Highlight the best-performing model and discuss its configuration, performance, and why it was chosen over others.
# ---

# %%
##Pickle
import pickle
with open('RandomForestRegression.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
##Pickle
import pickle
with open('SVCmodel.pkl', 'wb') as file:
    pickle.dump(SVCbest_model, file)

# %%
##Pickle
import pickle
with open('KNNmodel.pkl', 'wb') as file:
    pickle.dump(knn_model, file)

# %%
##Pickle
import pickle
with open('NaiveBeyersmodel.pkl', 'wb') as file:
    pickle.dump(nb_model, file)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
with open('vectorizer.pkl', 'wb') as vectorizer_file:
    pickle.dump(tfidf_vectorizer, vectorizer_file)

# %%
##Pickle
import pickle
with open('label_encoder.pkl', 'wb') as file:
    pickle.dump(le, file)

# %% [markdown]
# ---
# <a href=#nine></a>
# ## **Conclusion and Future Work**
# <a href=#cont>Back to Table of Contents</a>
# ---

# %% [markdown]
# ---
# <a href=#ten></a>
# ## **References**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Provide citations and sources of external content.
# * **Details:** List all the references and sources consulted during the project, including data sources, research papers, and documentation for tools and libraries used.
# ---

# %% [markdown]
# ## Additional Sections to Consider
#
# * ### Appendix:
# For any additional code, detailed tables, or extended data visualizations that are supplementary to the main content.
#
# * ### Contributors:
# If this is a group project, list the contributors and their roles or contributions to the project.
